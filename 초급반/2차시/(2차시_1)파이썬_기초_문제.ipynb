# %% [markdown]
# # 파이썬 기초 실습 노트북

# %% [markdown]
# ## 워밍업: 같이 풀어볼 3문제
# 아래 3문제는 본 실습(환전/조건문/논리/리스트/반복문) 들어가기 전에 손을 푸는 용도입니다.
#
# ### 워밍업 1: 계산기 맛보기 (입력 + 형변환)
# - 사용자로부터 정수 2개를 입력받으세요.
# - `합`, `차(첫번째-두번째)`, `곱`, `몫(정수 몫)`을 각각 출력하세요.
#
# ### 워밍업 2: 등급 판정 (다중 조건문)
# - 사용자로부터 점수(0~100)를 입력받으세요.
# - 아래 기준으로 등급을 출력하세요.
#   - 90 이상: A
#   - 80 이상: B
#   - 70 이상: C
#   - 60 이상: D
#   - 그 외: F
#
# ### 워밍업 3: 짝수 합 구하기 (반복문 + 조건문)
# - 1부터 20까지 숫자 중 **짝수만** 더한 합을 계산해 출력하세요.
# - `for`문, `range()`, `%`를 사용하세요.

# %%
# 워밍업 1: 계산기 맛보기
# 정수 2개를 입력받아 합/차/곱/몫(정수)을 출력해보세요.

# %%
# 워밍업 2: 등급 판정
# 점수(0~100)를 입력받아 A/B/C/D/F를 출력해보세요.

# %%
# 워밍업 3: 짝수 합 구하기
# 1~20 중 짝수만 더한 합을 출력해보세요.

# %% [markdown]
# ## 실습 1: 환전 키오스크 (데이터 타입의 이해)
# ### 상황
# 해외여행을 가기 위해 원화를 달러($)로 환전하려 합니다.
# 현재 환율은 **1달러당 1,350원**입니다.
#
# ### 요구사항
# 1. 사용자로부터 환전할 원화 금액을 입력받으세요.
# 2. 입력받은 금액을 달러로 계산하여 출력하세요.
# 3. 결과값은 소수점 없이 정수로만 나오게 하세요. (힌트: `int()`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 실습 2: 놀이공원 자유이용권 할인 (다중 조건문)
# ### 상황
# 놀이공원 입장료는 기본 **50,000원**입니다.
#
# ### 할인 규칙
# - 8세 미만: 무료 (0원)
# - 65세 이상: 50% 할인 (25,000원)
# - 그 외: 할인 없음 (50,000원)
#
# ### 요구사항
# 나이를 입력받아 최종 요금을 계산하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 실습 3: 로그인 보안 시스템 (논리 연산자)
# ### 상황
# 관리자 페이지에 접속하려고 합니다.
# 아이디와 비밀번호가 **모두** 맞아야 로그인이 성공합니다.
#
# ### 요구사항
# - 미리 정해진 아이디(`admin`)와 비밀번호(`1234`)를 변수에 저장합니다.
# - 사용자로부터 ID와 PW를 입력받습니다.
# - 두 개가 모두 일치하면 `환영합니다!`
# - 하나라도 틀리면 `접근 거부`를 출력하세요.

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 실습 4: 장바구니 품목 관리 (리스트 메서드)
# ### 상황
# 마트에서 장을 보고 있습니다.
# 장바구니에 물건을 넣고 빼는 과정을 코드로 구현합니다.
#
# ### 요구사항
# - 처음 장바구니 리스트는 `["사과", "우유", "계란"]`입니다.
# - `append()`를 사용하여 `"고기"`를 추가하세요.
# - `remove()`를 사용하여 `"우유"`를 삭제하세요.
# - 최종 장바구니 리스트와 총 품목 개수를 출력하세요. (힌트: `len()`)

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 실습 5: 369 게임의 시작 (반복문 + 조건문)
# ### 상황
# 1부터 20까지 숫자를 출력합니다.
#
# ### 규칙
# - 짝수일 때: `짝!`
# - 홀수일 때: 숫자 그대로 출력
#
# ### 요구사항
# - `for` 문과 `range()`를 사용하세요.
# - 나머지 연산자(`%`)로 짝수 여부를 판단하세요.
#
# ### 결과 예시
# `1, 짝!, 3, 짝!, 5 ...`
