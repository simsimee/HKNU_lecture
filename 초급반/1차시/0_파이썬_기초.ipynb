# %% [markdown]
# # 파이썬 기초 실습 노트북
#
# **목차**
# 1. Colab 소개 및 노트북 사용 방법
# 2. 파이썬 기초 문법
#     - 변수와 데이터 타입
#     - 연산자
#     - 문자열
#     - 리스트 · 튜플 · 딕셔너리
# 3. 제어문 (조건문 & 반복문)
# 4. 함수
# 5. 라이브러리 사용하기 (math, random, matplotlib)
# 6. 미니 실습 과제
#
# 각 섹션의 **코드 셀**을 실행하며 내용을 따라가 보세요! (Shift + Enter)

# %% [markdown]
# ## 1. Colab 소개 및 노트북 사용 방법
# Google Colaboratory(이하 "코랩")는 별도의 설치 없이 브라우저에서 파이썬 코드를 실행할 수 있는 서비스입니다.
#
# - **코드 셀**: 파이썬 코드를 작성하는 공간입니다.
# - **마크다운 셀**: 설명, 이미지, 수식 등을 작성할 수 있는 공간입니다.
#
# **셀 실행 방법**
# 1. 셀을 클릭합니다.
# 2. `Shift + Enter`를 눌러 실행합니다.
#
# 아래 셀을 선택 후 실행해 보세요!

# %%
print("Hello, Python!")

# %% [markdown]
# > ✅ 실행 결과가 출력되었다면 Colab 사용 준비 완료입니다!

# %% [markdown]
# ## 2. 파이썬 기초 문법
# ### 2-1) 변수와 데이터 타입
# 파이썬은 **동적 타이핑(dynamic typing)** 언어여서 변수를 선언할 때 타입을 명시하지 않아도 됩니다.

# %%
x = 10            # 정수(Integer)
y = 3.14          # 실수(Float)
name = 'Python'   # 문자열(String)
is_student = True # 불리언(Boolean)

print(type(x), type(y), type(name), type(is_student))

# %% [markdown]
# ### 2-2) 연산자
# +, -, *, /, //, %, ** 등 다양한 산술 연산자를 지원합니다.

# %%
a = 7
b = 3
print('a + b =', a + b)
print('a - b =', a - b)
print('a * b =', a * b)
print('a / b =', a / b)   # 실수 나눗셈
print('a // b =', a // b) # 몫
print('a % b =', a % b)   # 나머지
print('a ** b =', a ** b) # 거듭제곱

# %% [markdown]
# ### 2-3) 문자열
# 문자열은 작은따옴표(' ') 또는 큰따옴표(" ")로 둘 다 표현할 수 있습니다.

# %%
greeting = 'Hello'
target = "World"
sentence = greeting + ', ' + target + '!'
print(sentence)

# f-string 사용 예
age = 20
print(f'{target} is {age} years old.')

# %% [markdown]
# ### 2-4) 리스트 · 튜플 · 딕셔너리
# 자주 사용되는 3가지 자료구조를 살펴봅니다.

# %%
# 리스트 (list)
fruits = ['apple', 'banana', 'cherry']
fruits.append('orange')
print(fruits)

# 튜플 (tuple) - 불변(immutable)
point = (10, 20)
print(point[0])

# 딕셔너리 (dict)
student = {'name': 'Tom', 'age': 22}
student['major'] = 'AI'
print(student)

# %% [markdown]
# ## 3. 제어문 (조건문 & 반복문)
# ### 3-1) 조건문 if

# %%
score = 85
if score >= 90:
    print('A')
elif score >= 80:
    print('B')
else:
    print('C')

# %% [markdown]
# ### 3-2) 반복문 for · while

# %%
# for 문
for fruit in fruits:
    print(fruit)

# while 문
count = 3
while count > 0:
    print('Countdown:', count)
    count -= 1

# %% [markdown]
# ## 4. 함수
# 코드를 재사용하기 위한 블록을 정의합니다.

# %%
def add_numbers(a, b):
    """두 수를 더한 결과를 반환한다."""
    return a + b

result = add_numbers(5, 7)
print('5 + 7 =', result)

# %% [markdown]
# ## 5. 라이브러리 사용하기
# 표준 라이브러리와 외부 라이브러리를 불러와서 활용할 수 있습니다.

# %%
import math, random

print('π 값:', math.pi)
print('0~9 난수:', random.randint(0, 9))

# %%
# 간단한 시각화 예시 (matplotlib)
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [i**2 for i in x]

plt.plot(x, y, marker='o')
plt.title('y = x^2 그래프')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %%
# [실습] 조건문 만들기
# 간단한 음주 측정 프로그램
age = int(input("나이를 입력하세요: ")) # 입력받은 글자를 숫자로 변환

if age >= 20:
    print("성인입니다. 맥주를 주문할 수 있어요! 🍺")
else:
    print("미성년자입니다. 콜라를 드릴게요! 🥤")

# %%
# [실습] 반복문 만들기
# 리스트에 있는 모든 음식을 하나씩 꺼내기
foods = input("오늘 먹을 메뉴를 입력하세요: ").split()
print("--- 오늘 먹을 메뉴 ---")
for f in foods:
    print("- " + f)

# %% [markdown]
# ## 6. 미니 실습 과제
# 아래 문제를 풀어 보며 배운 내용을 복습해 보세요!
#
# 1. 사용자에게 이름을 입력 받아 "안녕하세요, <이름>님!" 을 출력하는 코드를 작성하세요.
# 2. 1부터 100까지의 정수 중 3의 배수의 합을 계산하는 코드를 작성하세요.

# %%
# 이곳에 코드를 작성해 보세요!

# %% [markdown]
# ---
# 이상으로 파이썬 기초 및 코랩 사용법 실습을 마칩니다. 수고하셨습니다! 🎉
